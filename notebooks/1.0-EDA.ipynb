# %% [markdown]
# # Import libraries and set up environment

# %%
# !unzip '/content/drive/MyDrive/filtered_paranmt.zip'
# Out:
# Archive:  /content/drive/MyDrive/filtered_paranmt.zip
#   inflating: filtered.tsv

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # EDA

# %%
df = pd.read_csv("filtered.tsv", sep='\t')

# %%
df.head()
# Out:
#    Unnamed: 0                                          reference  \
# 0           0  If Alkar is flooding her with psychic waste, t...
# 1           1                          Now you're getting nasty.
# 2           2           Well, we could spare your life, for one.
# 3           3          Ah! Monkey, you've got to snap out of it.
# 4           4                   I've got orders to put her down.
#
#                                          translation  similarity  lenght_diff  \
# 0  if Alkar floods her with her mental waste, it ...    0.785171     0.010309
# 1                        you're becoming disgusting.    0.749687     0.071429
# 2                      well, we can spare your life.    0.919051     0.268293
# 3                       monkey, you have to wake up.    0.664333     0.309524
# 4                         I have orders to kill her.    0.726639     0.181818
#
#     ref_tox   trn_tox
# 0  0.014195  0.981983
# 1  0.065473  0.999039
# 2  0.213313  0.985068
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0     similarity    lenght_diff        ref_tox  \
# count  577777.000000  577777.000000  577777.000000  577777.000000
# mean   288888.000000       0.758469       0.157652       0.541372
# std    166789.997578       0.092695       0.108057       0.457571
# min         0.000000       0.600001       0.000000       0.000033
# 25%    144444.000000       0.681105       0.066667       0.012171
# 50%    288888.000000       0.754439       0.141791       0.806795
# 75%    433332.000000       0.831244       0.238095       0.990469
# max    577776.000000       0.950000       0.400000       0.999724
#
#              trn_tox
# count  577777.000000
# mean        0.434490
# std         0.458904
# min         0.000033
# 25%         0.000707
# 50%         0.085133
# 75%         0.973739
# max         0.999730

# %%
df.shape
# Out:
# (577777, 7)

# %%
sub = df[df["ref_tox"]>=0.99]
sub.shape
# Out:
# (146577, 7)

# %%
sub = sub[sub["trn_tox"]<=0.01]
sub.shape
# Out:
# (113758, 7)

# %%
sub.head()
# Out:
#     Unnamed: 0                                          reference  \
# 6            6  They're all laughing at us, so we'll kick your...
# 13          13               Come on, Cal, leave that shit alone.
# 22          22     Real life starts the first time you fuck, kid.
# 25          25             Shit, this one I can't even pronounce.
# 26          26                                  I like that shit.
#
#                                 translation  similarity  lenght_diff  \
# 6   they're laughing at us. We'll show you.    0.618866     0.230769
# 13               come on, Cal, put it down.    0.660481     0.270270
# 22          boy, real life starts up first.    0.866697     0.319149
# 25       gosh, I can't even pronounce this.    0.777253     0.102564
# 26                               I love it.    0.697344     0.388889
#
#      ref_tox   trn_tox
# 6   0.999492  0.000131
# 13  0.999637  0.000279
# 22  0.998222  0.000114
# 25  0.997452  0.000120
# 26  0.999594  0.000043

# %%
sub.to_csv("subset.tsv",sep='\t')

# %%
sub = pd.read_csv("subset.tsv", sep="\t")

# %%
sub["text_ref_lenght"] = [len(row.split()) for row in sub["reference"].values]
sub["text_trn_lenght"] = [len(row.split()) for row in sub["translation"].values]

# %%
sub.describe()
# Out:
#         Unnamed: 0.1     Unnamed: 0     similarity    lenght_diff  \
# count  113758.000000  113758.000000  113758.000000  113758.000000
# mean   289236.000185  289236.000185       0.743513       0.184766
# std    167214.356243  167214.356243       0.089853       0.113131
# min         6.000000       6.000000       0.600003       0.000000
# 25%    144180.500000  144180.500000       0.667778       0.087500
# 50%    288669.000000  288669.000000       0.735086       0.178571
# 75%    434391.000000  434391.000000       0.810702       0.277778
# max    577775.000000  577775.000000       0.950000       0.400000
#
#              ref_tox        trn_tox  text_ref_lenght  text_trn_lenght
# count  113758.000000  113758.000000    113758.000000    113758.000000
# mean        0.997249       0.001115         9.454491         8.394460
# std         0.002566       0.002048         6.001780         5.657616
# min         0.990001       0.000033         1.000000         1.000000
# ...
